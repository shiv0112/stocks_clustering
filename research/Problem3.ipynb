# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
sns.set_style("whitegrid")

# %matplotlib inline

# %%
df = pd.read_csv("../data/data_stocks.csv")

# %%
df.head()
# Out:
#          DATE      SP500  NASDAQ.AAL  NASDAQ.AAPL  NASDAQ.ADBE  NASDAQ.ADI  \
# 0  1491226200  2363.6101     42.3300     143.6800     129.6300      82.040
# 1  1491226260  2364.1001     42.3600     143.7000     130.3200      82.080
# 2  1491226320  2362.6799     42.3100     143.6901     130.2250      82.030
# 3  1491226380  2364.3101     42.3700     143.6400     130.0729      82.000
# 4  1491226440  2364.8501     42.5378     143.6600     129.8800      82.035
#
#    NASDAQ.ADP  NASDAQ.ADSK  NASDAQ.AKAM  NASDAQ.ALXN  ...  NYSE.WYN  NYSE.XEC  \
# 0    102.2300      85.2200       59.760       121.52  ...    84.370   119.035
# 1    102.1400      85.6500       59.840       121.48  ...    84.370   119.035
# 2    102.2125      85.5100       59.795       121.93  ...    84.585   119.260
# 3    102.1400      85.4872       59.620       121.44  ...    84.460   119.260
# 4    102.0600      85.7001       59.620       121.60  ...    84.470   119.610
#
#    NYSE.XEL  NYSE.XL  NYSE.XOM  NYSE.XRX  NYSE.XYL  NYSE.YUM  NYSE.ZBH  \
# 0     44.40    39.88     82.03      7.36     50.22     63.86   122.000
# 1     44.11    39.88     82.03      7.38     50.22     63.74   121.770
# 2     44.09    39.98     82.02      7.36     50.12     63.75   121.700
# 3     44.25    39.99     82.02      7.35     50.16     63.88   121.700
# 4     44.11    39.96     82.03      7.36     50.20     63.91   121.695
#
#    NYSE.ZTS
# 0    53.350
# 1    53.350
# 2    53.365
# 3    53.380
# 4    53.240
#
# [5 rows x 502 columns]

# %% [markdown]
# # Problem 3

# %%
df=df.T

# %%
df.head()
# Out:
#                     0             1             2             3      \
# DATE         1.491226e+09  1.491226e+09  1.491226e+09  1.491226e+09
# SP500        2.363610e+03  2.364100e+03  2.362680e+03  2.364310e+03
# NASDAQ.AAL   4.233000e+01  4.236000e+01  4.231000e+01  4.237000e+01
# NASDAQ.AAPL  1.436800e+02  1.437000e+02  1.436901e+02  1.436400e+02
# NASDAQ.ADBE  1.296300e+02  1.303200e+02  1.302250e+02  1.300729e+02
#
#                     4             5             6             7      \
# DATE         1.491226e+09  1.491226e+09  1.491227e+09  1.491227e+09
# SP500        2.364850e+03  2.365620e+03  2.365200e+03  2.365290e+03
# NASDAQ.AAL   4.253780e+01  4.253990e+01  4.247000e+01  4.247000e+01
# NASDAQ.AAPL  1.436600e+02  1.437800e+02  1.438640e+02  1.438100e+02
# NASDAQ.ADBE  1.298800e+02  1.300700e+02  1.301800e+02  1.301400e+02
#
#                     8             9      ...         41256         41257  \
# DATE         1.491227e+09  1.491227e+09  ...  1.504209e+09  1.504209e+09
# SP500        2.364320e+03  2.364640e+03  ...  2.471890e+03  2.472770e+03
# NASDAQ.AAL   4.239000e+01  4.233000e+01  ...  4.472000e+01  4.473000e+01
# NASDAQ.AAPL  1.438150e+02  1.438000e+02  ...  1.641600e+02  1.640600e+02
# NASDAQ.ADBE  1.301000e+02  1.302100e+02  ...  1.550600e+02  1.550100e+02
#
#                     41258         41259         41260         41261  \
# DATE         1.504209e+09  1.504209e+09  1.504209e+09  1.504209e+09
# SP500        2.472900e+03  2.472640e+03  2.472020e+03  2.472220e+03
# NASDAQ.AAL   4.476000e+01  4.475000e+01  4.471000e+01  4.472000e+01
# NASDAQ.AAPL  1.641900e+02  1.642000e+02  1.641400e+02  1.641100e+02
# NASDAQ.ADBE  1.551200e+02  1.550900e+02  1.550400e+02  1.550900e+02
#
#                     41262         41263         41264         41265
# DATE         1.504209e+09  1.504209e+09  1.504210e+09  1.504210e+09
# SP500        2.471770e+03  2.470030e+03  2.471490e+03  2.471490e+03
# NASDAQ.AAL   4.473000e+01  4.474000e+01  4.471000e+01  4.474000e+01
# NASDAQ.AAPL  1.641200e+02  1.640100e+02  1.638800e+02  1.639800e+02
# NASDAQ.ADBE  1.551600e+02  1.550650e+02  1.549600e+02  1.551600e+02
#
# [5 rows x 41266 columns]

# %% [markdown]
# ## Principal Component Analysis

# %%
X = df.iloc[1:,:]
X
# Out:
#                  0          1          2          3          4          5      \
# SP500        2363.6101  2364.1001  2362.6799  2364.3101  2364.8501  2365.6201
# NASDAQ.AAL     42.3300    42.3600    42.3100    42.3700    42.5378    42.5399
# NASDAQ.AAPL   143.6800   143.7000   143.6901   143.6400   143.6600   143.7800
# NASDAQ.ADBE   129.6300   130.3200   130.2250   130.0729   129.8800   130.0700
# NASDAQ.ADI     82.0400    82.0800    82.0300    82.0000    82.0350    82.0400
# ...                ...        ...        ...        ...        ...        ...
# NYSE.XRX        7.3600     7.3800     7.3600     7.3500     7.3600     7.3600
# NYSE.XYL       50.2200    50.2200    50.1200    50.1600    50.2000    50.2000
# NYSE.YUM       63.8600    63.7400    63.7500    63.8800    63.9100    63.8400
# NYSE.ZBH      122.0000   121.7700   121.7000   121.7000   121.6950   121.8500
# NYSE.ZTS       53.3500    53.3500    53.3650    53.3800    53.2400    53.2200
#
#                 6        7          8          9      ...      41256  \
# SP500        2365.200  2365.29  2364.3201  2364.6399  ...  2471.8899
# NASDAQ.AAL     42.470    42.47    42.3900    42.3300  ...    44.7200
# NASDAQ.AAPL   143.864   143.81   143.8150   143.8000  ...   164.1600
# NASDAQ.ADBE   130.180   130.14   130.1000   130.2100  ...   155.0600
# NASDAQ.ADI     82.120    82.19    82.2300    82.1650  ...    83.7100
# ...               ...      ...        ...        ...  ...        ...
# NYSE.XRX        7.365     7.36     7.3700     7.3650  ...    32.2900
# NYSE.XYL       50.330    50.30    50.2500    50.2200  ...    62.0600
# NYSE.YUM       63.830    63.83    63.8500    63.8400  ...    76.8150
# NYSE.ZBH      122.100   122.28   121.8750   121.9300  ...   114.3600
# NYSE.ZTS       53.330    53.37    53.3300    53.4000  ...    62.7300
#
#                  41257      41258      41259     41260     41261     41262  \
# SP500        2472.7700  2472.8999  2472.6399  2472.020  2472.220  2471.770
# NASDAQ.AAL     44.7300    44.7600    44.7500    44.710    44.720    44.730
# NASDAQ.AAPL   164.0600   164.1900   164.2000   164.140   164.110   164.120
# NASDAQ.ADBE   155.0100   155.1200   155.0900   155.040   155.090   155.160
# NASDAQ.ADI     83.7000    83.6300    83.6900    83.660    83.670    83.650
# ...                ...        ...        ...       ...       ...       ...
# NYSE.XRX       32.2950    32.3000    32.2950    32.295    32.285    32.295
# NYSE.XYL       62.1000    62.1050    62.1050    62.095    62.110    62.100
# NYSE.YUM       76.8100    76.8799    76.9100    76.885    76.880    76.900
# NYSE.ZBH      114.3100   114.3500   114.3200   114.300   114.310   114.330
# NYSE.ZTS       62.7225    62.7400    62.7400    62.730    62.725    62.710
#
#                 41263      41264    41265
# SP500        2470.030  2471.4900  2471.49
# NASDAQ.AAL     44.740    44.7100    44.74
# NASDAQ.AAPL   164.010   163.8800   163.98
# NASDAQ.ADBE   155.065   154.9600   155.16
# NASDAQ.ADI     83.620    83.5800    83.69
# ...               ...        ...      ...
# NYSE.XRX       32.290    32.2750    32.27
# NYSE.XYL       62.090    62.0750    62.07
# NYSE.YUM       76.880    76.8300    76.81
# NYSE.ZBH      114.310   114.2300   114.28
# NYSE.ZTS       62.685    62.6301    62.68
#
# [501 rows x 41266 columns]

# %%
y = df.iloc[0,:]
y
# Out:
# 0        1.491226e+09
# 1        1.491226e+09
# 2        1.491226e+09
# 3        1.491226e+09
# 4        1.491226e+09
#              ...
# 41261    1.504209e+09
# 41262    1.504209e+09
# 41263    1.504209e+09
# 41264    1.504210e+09
# 41265    1.504210e+09
# Name: DATE, Length: 41266, dtype: float64

# %% [markdown]
# #### Data Standardization

# %%
from sklearn.preprocessing import StandardScaler
X_std = StandardScaler().fit_transform(X)

# %%
import seaborn as sns
from sklearn.decomposition import PCA

sns.set_style('whitegrid')
pca = PCA().fit(X_std)
plt.plot(np.cumsum(pca.explained_variance_ratio_))
plt.xlabel('number of components')
plt.ylabel('cumulative explained variance')
plt.show()

# %%
pca = PCA(n_components=10)
pca.fit(X_std)
print('explained variance :')
print('--------------------------------------------------------------------')
print(pca.explained_variance_)
print('--------------------------------------------------------------------')
print('PCA Components : ')
print('--------------------------------------------------------------------')
print(pca.components_)
print('--------------------------------------------------------------------')
X_transformed = pca.transform(X_std)
print('Transformed Feature values first five rows :')
print('--------------------------------------------------------------------')
print(X_transformed[:5,:])
print('--------------------------------------------------------------------')
print('Transformed Feature shape :')
print('--------------------------------------------------------------------')
print(X_transformed.shape)
print('--------------------------------------------------------------------')
print('Original Feature shape :')
print('--------------------------------------------------------------------')
print(X_std.shape)
print('--------------------------------------------------------------------')
print('Restransformed Feature shape :')
print('--------------------------------------------------------------------')
X_retransformed = pca.inverse_transform(X_transformed)
print(X_retransformed.shape)
print('--------------------------------------------------------------------')
print('Retransformed Feature values first five rows :')
print('--------------------------------------------------------------------')
print(X_retransformed[:5,:])
print('--------------------------------------------------------------------')
# Out:
# explained variance :
# --------------------------------------------------------------------
# [4.12410017e+04 7.16685582e+01 1.50655992e+01 9.71023421e+00
#  3.86316450e+00 1.60384851e+00 1.03871384e+00 7.97357989e-01
#  5.53728414e-01 4.15453639e-01]
# --------------------------------------------------------------------
# PCA Components :
# --------------------------------------------------------------------
# [[ 0.00491446  0.00491475  0.00491507 ...  0.00491842  0.00491846
#    0.0049184 ]
#  [ 0.00806896  0.00800282  0.00793144 ... -0.00658309 -0.00656673
#   -0.00658065]
#  [-0.00760186 -0.00736632 -0.00715671 ... -0.0048557  -0.00490797
#   -0.00481143]
#  ...
#  [ 0.00499361  0.00475233  0.0037726  ... -0.00485807 -0.00487505
#   -0.00506577]
#  [-0.00612901 -0.00652873 -0.00679263 ...  0.00662397  0.00645128
#    0.00659493]
#  [ 0.00079681  0.00077259  0.00061852 ...  0.00613522  0.00614684
#    0.00599074]]
# --------------------------------------------------------------------
# Transformed Feature values first five rows :
# --------------------------------------------------------------------
# [[ 2.85155202e+03  1.68123590e+01 -2.54919759e+01 -1.65265487e+01
#   -1.21118858e+01  2.12922315e+00  2.76727040e-01 -1.43389754e+00
#   -3.52136292e+00 -1.07202561e+00]
#  [-6.73221228e+01 -2.14177601e+00  1.84927351e+00  1.73626658e+00
#   -4.88401329e-01  3.28110713e-02 -9.23770807e-01 -4.37025024e-02
#   -2.88693716e-01 -1.57666609e-01]
#  [ 5.90461410e+01 -1.58090211e+00 -1.77856427e+00 -3.68065098e+00
#    3.99560589e+00  1.31892968e+00  1.05304026e+00 -1.02429691e+00
#   -1.66505657e+00  1.15078625e+00]
#  [ 4.77249784e+01 -5.52746498e+00 -8.38849976e-01 -1.63537675e+00
#    8.25799999e-01  4.61141399e-01  6.86485686e-01 -8.84627408e-01
#    4.55431255e-01  4.57816437e-01]
#  [-2.82165076e+01  7.80005490e-01  5.39506158e-01 -7.00617755e-01
#   -1.40310218e-01  1.32315755e+00  3.46914632e-01 -6.70449617e-01
#    8.76291958e-02  4.82145816e-01]]
# --------------------------------------------------------------------
# Transformed Feature shape :
# --------------------------------------------------------------------
# (501, 10)
# --------------------------------------------------------------------
# Original Feature shape :
# --------------------------------------------------------------------
# (501, 41266)
# --------------------------------------------------------------------
# Restransformed Feature shape :
# --------------------------------------------------------------------
# (501, 41266)
# --------------------------------------------------------------------
# Retransformed Feature values first five rows :
# --------------------------------------------------------------------
# [[14.39709293 14.38719509 14.3872666  ... 14.1131394  14.1161104
#   14.113421  ]
#  [-0.36111276 -0.36052928 -0.35973717 ... -0.35137413 -0.35143677
#   -0.35157543]
#  [ 0.27992596  0.28087977  0.28144539 ...  0.35514251  0.35540272
#    0.35586512]
#  [ 0.18808091  0.18833849  0.18913628 ...  0.3049568   0.30484295
#    0.30530903]
#  [-0.13416907 -0.13417832 -0.13349159 ... -0.13460669 -0.13452129
#   -0.13438234]]
# --------------------------------------------------------------------

# %% [markdown]
# ## K-Means

# %%
from sklearn.cluster import KMeans

wcss=[]
for i in range(1, 21):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 0)
    kmeans.fit(X_transformed)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 21), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('Mean Squared Errors')
plt.figure(figsize=(10,8))
plt.show()

# %%
import scikitplot
scikitplot.cluster.plot_elbow_curve(KMeans(),X_transformed,cluster_ranges=range(1,20))
# Out:
# <AxesSubplot:title={'center':'Elbow Plot'}, xlabel='Number of clusters', ylabel='Sum of Squared Errors'>

# %%
X_trans = pd.DataFrame(X_transformed) 
X_trans
# Out:
#                0          1          2          3          4         5  \
# 0    2851.552017  16.812359 -25.491976 -16.526549 -12.111886  2.129223
# 1     -67.322123  -2.141776   1.849274   1.736267  -0.488401  0.032811
# 2      59.046141  -1.580902  -1.778564  -3.680651   3.995606  1.318930
# 3      47.724978  -5.527465  -0.838850  -1.635377   0.825800  0.461141
# 4     -28.216508   0.780005   0.539506  -0.700618  -0.140310  1.323158
# ..           ...        ...        ...        ...        ...       ...
# 496  -102.418620 -13.374199  -2.456842   1.278106  -2.631316 -1.987918
# 497   -58.909653  -3.515838  -1.229148  -0.482998   0.715759 -0.051302
# 498   -37.768773  -3.790280   0.917634  -0.762794   0.469153  0.166726
# 499    23.384796   2.245973   2.415229   2.869741  -4.072576 -0.481108
# 500   -51.988519  -2.615004   2.338161  -0.178834   0.327281 -0.121130
#
#             6         7         8         9
# 0    0.276727 -1.433898 -3.521363 -1.072026
# 1   -0.923771 -0.043703 -0.288694 -0.157667
# 2    1.053040 -1.024297 -1.665057  1.150786
# 3    0.686486 -0.884627  0.455431  0.457816
# 4    0.346915 -0.670450  0.087629  0.482146
# ..        ...       ...       ...       ...
# 496  0.424595  2.160934  0.098362 -0.480371
# 497  0.076366  0.147101 -0.233860  0.194640
# 498 -0.035188  0.499362 -0.027870  0.351769
# 499  0.719478 -0.361450  1.353845 -1.019922
# 500 -0.005569  0.257108 -0.169782  0.397829
#
# [501 rows x 10 columns]

# %% [markdown]
# ### K-Means with 5 clusters

# %%
k_means = KMeans(n_clusters=5,random_state=42,init='k-means++')
X_trans['cluster number'] = k_means.fit_predict(X_trans)
X_trans['cluster number'].unique()
# Out:
# array([1, 0, 3, 2, 4])

# %%
y_kmeans = kmeans.fit_predict(X_transformed)
y_kmeans
# Out:
# array([ 2, 12,  4,  4,  0,  9,  9, 12, 17, 12, 10,  4,  1, 19,  3,  7, 18,
#         7, 13, 17, 19,  0, 15,  0,  7, 17,  4,  7, 12, 17, 19,  0, 10, 10,
#        19,  0,  9,  7,  6, 19,  7, 19,  4, 12,  4, 17, 17, 10,  7,  7,  7,
#         0,  1,  1, 12,  7,  9, 10, 12, 11,  4, 11, 17, 12,  7, 17, 14, 13,
#        13,  9,  7,  4,  9, 10,  0, 12, 12,  0,  7,  7, 10,  0,  4,  7, 13,
#         4, 10, 10,  3, 19, 10, 19,  5, 12, 12, 19,  0,  6, 19, 19,  0,  0,
#        10,  0,  7,  9,  7,  7,  0, 19,  0, 18,  7, 13, 13, 17,  0, 13,  7,
#         4, 17, 19, 19, 12, 19, 17,  0, 13, 12, 17, 12,  3, 19,  0, 10,  4,
#         0,  3, 19, 12,  9, 19,  9, 13, 13,  0, 19,  4, 17, 17, 12, 11, 17,
#        12, 12,  4,  0, 17, 10, 11, 13,  0, 13, 11,  8, 11, 10, 19, 12, 19,
#        15, 11, 12, 12, 12, 12,  6, 12, 19, 11, 10, 12, 17, 19,  7,  0,  9,
#         4,  7, 19,  9, 19,  7,  7, 12, 10,  4,  0, 17,  0, 16,  4, 12,  0,
#         7, 13, 10, 12,  9,  3, 12, 10, 19, 13,  7, 10,  0,  9, 17,  0, 12,
#         0, 17, 19,  0,  9,  7, 13,  9, 13,  9, 13, 19, 13, 13,  9, 13, 19,
#         7,  0, 17, 13,  4,  0, 13, 13, 19, 13, 19, 19, 19, 18,  0,  0, 19,
#         9,  7,  0, 10, 19, 10, 11,  7, 13, 19, 12, 12,  0, 17,  7, 19, 11,
#         7, 10, 19,  7,  7, 13, 13, 10,  3, 11, 12, 10, 13,  0,  7,  4, 12,
#        12, 12, 17, 19, 10, 10,  7,  7,  9, 10,  9,  3,  4, 19, 17, 19, 10,
#        13,  7, 17,  4,  7, 12, 12, 17,  7, 13, 12,  0, 10, 10, 17, 10, 19,
#        12,  7, 10,  7,  9, 12, 12, 12, 12,  4, 11, 13, 18,  0,  7,  0, 10,
#        19, 19, 13, 10, 17,  9, 19,  7,  4,  4, 17, 13, 12,  3,  9,  3,  0,
#        11, 12,  0, 17, 10, 12, 19, 10, 12, 13,  4, 10,  7,  4,  7,  7, 10,
#        19,  7, 18,  7, 10, 17, 19, 12, 19, 12, 13, 12, 19, 19, 12,  9,  7,
#        19, 13, 12,  4, 10, 19, 19, 17, 17, 19, 13,  9,  7,  0,  9,  3,  0,
#         9,  7, 17,  4, 19,  9, 19, 10, 12, 13, 10,  0,  0,  4,  3, 10, 19,
#         4, 19,  7, 12, 15, 19, 17,  0,  9,  4, 12,  4,  4,  9, 19, 13, 11,
#         4,  7,  4, 12,  7, 13, 18,  0, 19, 13,  0,  0, 11, 17, 19, 13, 19,
#         9, 12, 10, 10,  0,  7, 17, 11, 12,  9,  9,  9, 12, 17, 13,  9, 19,
#        19, 17, 13, 19, 12, 11, 19, 12, 11,  0,  7,  0, 19, 10,  7,  9,  9,
#        12, 12,  0, 10, 19,  0, 17, 19])

# %%
plt.scatter(X_transformed[y_kmeans == 0, 0], X_transformed[y_kmeans == 0, 1], s = 100, c = 'red', label = 'Cluster 1')
plt.scatter(X_transformed[y_kmeans == 1, 0], X_transformed[y_kmeans == 1, 1], s = 100, c = 'blue', label = 'Cluster 2')
plt.scatter(X_transformed[y_kmeans == 2, 0], X_transformed[y_kmeans == 2, 1], s = 100, c = 'green', label = 'Cluster 3')
plt.scatter(X_transformed[y_kmeans == 3, 0], X_transformed[y_kmeans == 3, 1], s = 100, c = 'magenta', label = 'Cluster 4')
plt.scatter(X_transformed[y_kmeans == 4, 0], X_transformed[y_kmeans == 4, 1], s = 100, c = 'orange', label = 'Cluster 5')
#plt.scatter(kmeans.cluster_centers_[:, 0], kmeans.cluster_centers_[:, 1], s = 300, c = 'yellow', label = 'Centroids')
plt.title('Clusters of stocks')
plt.xlabel('Principal Component (1)')
plt.ylabel('Principal Component (2)')
plt.legend()
plt.show()

# %%
X_trans
# Out:
#                0          1          2          3          4         5  \
# 0    2851.552017  16.812359 -25.491976 -16.526549 -12.111886  2.129223
# 1     -67.322123  -2.141776   1.849274   1.736267  -0.488401  0.032811
# 2      59.046141  -1.580902  -1.778564  -3.680651   3.995606  1.318930
# 3      47.724978  -5.527465  -0.838850  -1.635377   0.825800  0.461141
# 4     -28.216508   0.780005   0.539506  -0.700618  -0.140310  1.323158
# ..           ...        ...        ...        ...        ...       ...
# 496  -102.418620 -13.374199  -2.456842   1.278106  -2.631316 -1.987918
# 497   -58.909653  -3.515838  -1.229148  -0.482998   0.715759 -0.051302
# 498   -37.768773  -3.790280   0.917634  -0.762794   0.469153  0.166726
# 499    23.384796   2.245973   2.415229   2.869741  -4.072576 -0.481108
# 500   -51.988519  -2.615004   2.338161  -0.178834   0.327281 -0.121130
#
#             6         7         8         9  cluster number
# 0    0.276727 -1.433898 -3.521363 -1.072026               1
# 1   -0.923771 -0.043703 -0.288694 -0.157667               0
# 2    1.053040 -1.024297 -1.665057  1.150786               3
# 3    0.686486 -0.884627  0.455431  0.457816               3
# 4    0.346915 -0.670450  0.087629  0.482146               0
# ..        ...       ...       ...       ...             ...
# 496  0.424595  2.160934  0.098362 -0.480371               0
# 497  0.076366  0.147101 -0.233860  0.194640               0
# 498 -0.035188  0.499362 -0.027870  0.351769               0
# 499  0.719478 -0.361450  1.353845 -1.019922               3
# 500 -0.005569  0.257108 -0.169782  0.397829               0
#
# [501 rows x 11 columns]

# %%
X_trans.set_index(X.index,inplace=True)

# %%
X_trans.index[X_trans['cluster number']==4].tolist()
# Out:
# ['NASDAQ.AVGO',
#  'NASDAQ.BIIB',
#  'NASDAQ.CHTR',
#  'NASDAQ.EQIX',
#  'NASDAQ.ORLY',
#  'NASDAQ.REGN',
#  'NASDAQ.ULTA',
#  'NYSE.ADS',
#  'NYSE.AGN',
#  'NYSE.BCR',
#  'NYSE.BLK',
#  'NYSE.CMG',
#  'NYSE.COO',
#  'NYSE.ESS',
#  'NYSE.GS',
#  'NYSE.HUM',
#  'NYSE.LMT',
#  'NYSE.MHK',
#  'NYSE.MLM',
#  'NYSE.NOC',
#  'NYSE.PSA',
#  'NYSE.ROP',
#  'NYSE.SHW',
#  'NYSE.TDG']

# %%
X_trans.index[X_trans['cluster number']==3].tolist()
# Out:
# ['NASDAQ.AAPL',
#  'NASDAQ.ADBE',
#  'NASDAQ.ADP',
#  'NASDAQ.ADSK',
#  'NASDAQ.ALXN',
#  'NASDAQ.AMGN',
#  'NASDAQ.CELG',
#  'NASDAQ.CME',
#  'NASDAQ.COST',
#  'NASDAQ.CTAS',
#  'NASDAQ.EA',
#  'NASDAQ.EXPE',
#  'NASDAQ.FB',
#  'NASDAQ.FFIV',
#  'NASDAQ.FISV',
#  'NASDAQ.HAS',
#  'NASDAQ.HSIC',
#  'NASDAQ.IDXX',
#  'NASDAQ.ILMN',
#  'NASDAQ.INCY',
#  'NASDAQ.INTU',
#  'NASDAQ.KLAC',
#  'NASDAQ.LRCX',
#  'NASDAQ.MAR',
#  'NASDAQ.NFLX',
#  'NASDAQ.NVDA',
#  'NASDAQ.SWKS',
#  'NASDAQ.VRTX',
#  'NASDAQ.WLTW',
#  'NASDAQ.WYNN',
#  'NYSE.AAP',
#  'NYSE.ACN',
#  'NYSE.AET',
#  'NYSE.AIZ',
#  'NYSE.ALB',
#  'NYSE.AMG',
#  'NYSE.AMP',
#  'NYSE.AMT',
#  'NYSE.ANTM',
#  'NYSE.AON',
#  'NYSE.APD',
#  'NYSE.ARE',
#  'NYSE.AVB',
#  'NYSE.AYI',
#  'NYSE.BA',
#  'NYSE.BDX',
#  'NYSE.BRK.B',
#  'NYSE.BXP',
#  'NYSE.CAT',
#  'NYSE.CB',
#  'NYSE.CCI',
#  'NYSE.CI',
#  'NYSE.CLX',
#  'NYSE.CMI',
#  'NYSE.COL',
#  'NYSE.CVX',
#  'NYSE.CXO',
#  'NYSE.DE',
#  'NYSE.DGX',
#  'NYSE.DIS',
#  'NYSE.DLR',
#  'NYSE.DTE',
#  'NYSE.ECL',
#  'NYSE.EFX',
#  'NYSE.EL',
#  'NYSE.EW',
#  'NYSE.FDX',
#  'NYSE.FRT',
#  'NYSE.GD',
#  'NYSE.GWW',
#  'NYSE.HD',
#  'NYSE.HON',
#  'NYSE.HRS',
#  'NYSE.HSY',
#  'NYSE.IBM',
#  'NYSE.IFF',
#  'NYSE.IT',
#  'NYSE.ITW',
#  'NYSE.JNJ',
#  'NYSE.KMB',
#  'NYSE.KSU',
#  'NYSE.LH',
#  'NYSE.LLL',
#  'NYSE.MA',
#  'NYSE.MAA',
#  'NYSE.MCD',
#  'NYSE.MCK',
#  'NYSE.MCO',
#  'NYSE.MKC',
#  'NYSE.MMM',
#  'NYSE.MON',
#  'NYSE.MTB',
#  'NYSE.NEE',
#  'NYSE.NSC',
#  'NYSE.PEP',
#  'NYSE.PH',
#  'NYSE.PM',
#  'NYSE.PNC',
#  'NYSE.PPG',
#  'NYSE.PRU',
#  'NYSE.PVH',
#  'NYSE.PX',
#  'NYSE.PXD',
#  'NYSE.RCL',
#  'NYSE.ROK',
#  'NYSE.RTN',
#  'NYSE.SJM',
#  'NYSE.SLG',
#  'NYSE.SNA',
#  'NYSE.SPG',
#  'NYSE.SPGI',
#  'NYSE.SRE',
#  'NYSE.STZ',
#  'NYSE.SWK',
#  'NYSE.SYK',
#  'NYSE.TMO',
#  'NYSE.TRV',
#  'NYSE.TWX',
#  'NYSE.UHS',
#  'NYSE.UNH',
#  'NYSE.UNP',
#  'NYSE.UPS',
#  'NYSE.URI',
#  'NYSE.UTX',
#  'NYSE.V',
#  'NYSE.VAR',
#  'NYSE.VMC',
#  'NYSE.WAT',
#  'NYSE.WHR',
#  'NYSE.WYN',
#  'NYSE.XEC',
#  'NYSE.ZBH']

# %%
X_trans.index[X_trans['cluster number']==2].tolist()
# Out:
# ['NASDAQ.AMZN', 'NASDAQ.GOOG', 'NASDAQ.GOOGL', 'NASDAQ.ISRG', 'NYSE.AZO']

# %%
X_trans.index[X_trans['cluster number']==1].tolist()
# Out:
# ['SP500', 'NASDAQ.PCLN']

# %%
X_trans.index[X_trans['cluster number']==0].tolist()
# Out:
# ['NASDAQ.AAL',
#  'NASDAQ.ADI',
#  'NASDAQ.AKAM',
#  'NASDAQ.AMAT',
#  'NASDAQ.AMD',
#  'NASDAQ.ATVI',
#  'NASDAQ.BBBY',
#  'NASDAQ.CA',
#  'NASDAQ.CBOE',
#  'NASDAQ.CERN',
#  'NASDAQ.CHRW',
#  'NASDAQ.CINF',
#  'NASDAQ.CMCSA',
#  'NASDAQ.CSCO',
#  'NASDAQ.CSX',
#  'NASDAQ.CTSH',
#  'NASDAQ.CTXS',
#  'NASDAQ.DISCA',
#  'NASDAQ.DISCK',
#  'NASDAQ.DISH',
#  'NASDAQ.DLTR',
#  'NASDAQ.EBAY',
#  'NASDAQ.ESRX',
#  'NASDAQ.ETFC',
#  'NASDAQ.EXPD',
#  'NASDAQ.FAST',
#  'NASDAQ.FITB',
#  'NASDAQ.FLIR',
#  'NASDAQ.FOX',
#  'NASDAQ.FOXA',
#  'NASDAQ.GILD',
#  'NASDAQ.GRMN',
#  'NASDAQ.GT',
#  'NASDAQ.HBAN',
#  'NASDAQ.HOLX',
#  'NASDAQ.INFO',
#  'NASDAQ.INTC',
#  'NASDAQ.JBHT',
#  'NASDAQ.KHC',
#  'NASDAQ.LKQ',
#  'NASDAQ.MAT',
#  'NASDAQ.MCHP',
#  'NASDAQ.MDLZ',
#  'NASDAQ.MNST',
#  'NASDAQ.MSFT',
#  'NASDAQ.MU',
#  'NASDAQ.MYL',
#  'NASDAQ.NAVI',
#  'NASDAQ.NDAQ',
#  'NASDAQ.NTAP',
#  'NASDAQ.NTRS',
#  'NASDAQ.NWS',
#  'NASDAQ.NWSA',
#  'NASDAQ.PAYX',
#  'NASDAQ.PBCT',
#  'NASDAQ.PCAR',
#  'NASDAQ.PDCO',
#  'NASDAQ.PYPL',
#  'NASDAQ.QCOM',
#  'NASDAQ.QRVO',
#  'NASDAQ.ROST',
#  'NASDAQ.SBUX',
#  'NASDAQ.SNI',
#  'NASDAQ.SNPS',
#  'NASDAQ.SPLS',
#  'NASDAQ.SRCL',
#  'NASDAQ.STX',
#  'NASDAQ.SYMC',
#  'NASDAQ.TRIP',
#  'NASDAQ.TROW',
#  'NASDAQ.TSCO',
#  'NASDAQ.TXN',
#  'NASDAQ.VIAB',
#  'NASDAQ.VRSK',
#  'NASDAQ.VRSN',
#  'NASDAQ.WBA',
#  'NASDAQ.WDC',
#  'NASDAQ.WFM',
#  'NASDAQ.XLNX',
#  'NASDAQ.XRAY',
#  'NASDAQ.ZION',
#  'NYSE.A',
#  'NYSE.ABBV',
#  'NYSE.ABC',
#  'NYSE.ABT',
#  'NYSE.ADM',
#  'NYSE.AEE',
#  'NYSE.AEP',
#  'NYSE.AES',
#  'NYSE.AFL',
#  'NYSE.AIG',
#  'NYSE.AIV',
#  'NYSE.AJG',
#  'NYSE.ALK',
#  'NYSE.ALL',
#  'NYSE.ALLE',
#  'NYSE.AME',
#  'NYSE.AN',
#  'NYSE.APA',
#  'NYSE.APC',
#  'NYSE.APH',
#  'NYSE.ARNC',
#  'NYSE.AVY',
#  'NYSE.AWK',
#  'NYSE.AXP',
#  'NYSE.BAC',
#  'NYSE.BAX',
#  'NYSE.BBT',
#  'NYSE.BBY',
#  'NYSE.BEN',
#  'NYSE.BF.B',
#  'NYSE.BHI',
#  'NYSE.BK',
#  'NYSE.BLL',
#  'NYSE.BMY',
#  'NYSE.BSX',
#  'NYSE.BWA',
#  'NYSE.C',
#  'NYSE.CAG',
#  'NYSE.CAH',
#  'NYSE.CBG',
#  'NYSE.CBS',
#  'NYSE.CCL',
#  'NYSE.CF',
#  'NYSE.CFG',
#  'NYSE.CHD',
#  'NYSE.CHK',
#  'NYSE.CL',
#  'NYSE.CMA',
#  'NYSE.CMS',
#  'NYSE.CNC',
#  'NYSE.CNP',
#  'NYSE.COF',
#  'NYSE.COG',
#  'NYSE.COH',
#  'NYSE.COP',
#  'NYSE.COTY',
#  'NYSE.CPB',
#  'NYSE.CRM',
#  'NYSE.CSRA',
#  'NYSE.CTL',
#  'NYSE.CVS',
#  'NYSE.D',
#  'NYSE.DAL',
#  'NYSE.DD',
#  'NYSE.DFS',
#  'NYSE.DG',
#  'NYSE.DHI',
#  'NYSE.DHR',
#  'NYSE.DLPH',
#  'NYSE.DOV',
#  'NYSE.DOW',
#  'NYSE.DPS',
#  'NYSE.DRI',
#  'NYSE.DUK',
#  'NYSE.DVA',
#  'NYSE.DVN',
#  'NYSE.DXC',
#  'NYSE.ED',
#  'NYSE.EIX',
#  'NYSE.EMN',
#  'NYSE.EMR',
#  'NYSE.EOG',
#  'NYSE.EQR',
#  'NYSE.EQT',
#  'NYSE.ES',
#  'NYSE.ETN',
#  'NYSE.ETR',
#  'NYSE.EVHC',
#  'NYSE.EXC',
#  'NYSE.EXR',
#  'NYSE.F',
#  'NYSE.FBHS',
#  'NYSE.FCX',
#  'NYSE.FE',
#  'NYSE.FIS',
#  'NYSE.FL',
#  'NYSE.FLR',
#  'NYSE.FLS',
#  'NYSE.FMC',
#  'NYSE.FTI',
#  'NYSE.FTV',
#  'NYSE.GE',
#  'NYSE.GGP',
#  'NYSE.GIS',
#  'NYSE.GLW',
#  'NYSE.GM',
#  'NYSE.GPC',
#  'NYSE.GPN',
#  'NYSE.GPS',
#  'NYSE.HAL',
#  'NYSE.HBI',
#  'NYSE.HCA',
#  'NYSE.HCN',
#  'NYSE.HCP',
#  'NYSE.HES',
#  'NYSE.HIG',
#  'NYSE.HOG',
#  'NYSE.HP',
#  'NYSE.HPE',
#  'NYSE.HPQ',
#  'NYSE.HRB',
#  'NYSE.HRL',
#  'NYSE.HST',
#  'NYSE.ICE',
#  'NYSE.IP',
#  'NYSE.IPG',
#  'NYSE.IR',
#  'NYSE.IRM',
#  'NYSE.IVZ',
#  'NYSE.JCI',
#  'NYSE.JEC',
#  'NYSE.JNPR',
#  'NYSE.JPM',
#  'NYSE.JWN',
#  'NYSE.K',
#  'NYSE.KEY',
#  'NYSE.KIM',
#  'NYSE.KMI',
#  'NYSE.KMX',
#  'NYSE.KO',
#  'NYSE.KORS',
#  'NYSE.KR',
#  'NYSE.KSS',
#  'NYSE.L',
#  'NYSE.LB',
#  'NYSE.LEG',
#  'NYSE.LEN',
#  'NYSE.LLY',
#  'NYSE.LNC',
#  'NYSE.LNT',
#  'NYSE.LOW',
#  'NYSE.LUK',
#  'NYSE.LUV',
#  'NYSE.LVLT',
#  'NYSE.LYB',
#  'NYSE.M',
#  'NYSE.MAC',
#  'NYSE.MAS',
#  'NYSE.MDT',
#  'NYSE.MET',
#  'NYSE.MMC',
#  'NYSE.MNK',
#  'NYSE.MO',
#  'NYSE.MOS',
#  'NYSE.MPC',
#  'NYSE.MRK',
#  'NYSE.MRO',
#  'NYSE.MS',
#  'NYSE.MSI',
#  'NYSE.MUR',
#  'NYSE.NBL',
#  'NYSE.NEM',
#  'NYSE.NFX',
#  'NYSE.NI',
#  'NYSE.NKE',
#  'NYSE.NLSN',
#  'NYSE.NOV',
#  'NYSE.NRG',
#  'NYSE.NUE',
#  'NYSE.NWL',
#  'NYSE.O',
#  'NYSE.OKE',
#  'NYSE.OMC',
#  'NYSE.ORCL',
#  'NYSE.OXY',
#  'NYSE.PCG',
#  'NYSE.PEG',
#  'NYSE.PFE',
#  'NYSE.PFG',
#  'NYSE.PG',
#  'NYSE.PGR',
#  'NYSE.PHM',
#  'NYSE.PKI',
#  'NYSE.PLD',
#  'NYSE.PNR',
#  'NYSE.PNW',
#  'NYSE.PPL',
#  'NYSE.PRGO',
#  'NYSE.PSX',
#  'NYSE.PWR',
#  'NYSE.RAI',
#  'NYSE.REG',
#  'NYSE.RF',
#  'NYSE.RHI',
#  'NYSE.RHT',
#  'NYSE.RIG',
#  'NYSE.RJF',
#  'NYSE.RL',
#  'NYSE.RRC',
#  'NYSE.RSG',
#  'NYSE.SCG',
#  'NYSE.SCHW',
#  'NYSE.SEE',
#  'NYSE.SIG',
#  'NYSE.SLB',
#  'NYSE.SO',
#  'NYSE.STI',
#  'NYSE.STT',
#  'NYSE.SYF',
#  'NYSE.SYY',
#  'NYSE.T',
#  'NYSE.TAP',
#  'NYSE.TEL',
#  'NYSE.TGT',
#  'NYSE.TIF',
#  'NYSE.TJX',
#  'NYSE.TMK',
#  'NYSE.TSN',
#  'NYSE.TSO',
#  'NYSE.TSS',
#  'NYSE.TXT',
#  'NYSE.UA',
#  'NYSE.UAA',
#  'NYSE.UAL',
#  'NYSE.UDR',
#  'NYSE.UNM',
#  'NYSE.USB',
#  'NYSE.VFC',
#  'NYSE.VLO',
#  'NYSE.VNO',
#  'NYSE.VTR',
#  'NYSE.VZ',
#  'NYSE.WEC',
#  'NYSE.WFC',
#  'NYSE.WM',
#  'NYSE.WMB',
#  'NYSE.WMT',
#  'NYSE.WRK',
#  'NYSE.WU',
#  'NYSE.WY',
#  'NYSE.XEL',
#  'NYSE.XL',
#  'NYSE.XOM',
#  'NYSE.XRX',
#  'NYSE.XYL',
#  'NYSE.YUM',
#  'NYSE.ZTS']

# %%
X_trans
# Out:
#                        0          1          2          3          4  \
# SP500        2851.552017  16.812359 -25.491976 -16.526549 -12.111886
# NASDAQ.AAL    -67.322123  -2.141776   1.849274   1.736267  -0.488401
# NASDAQ.AAPL    59.046141  -1.580902  -1.778564  -3.680651   3.995606
# NASDAQ.ADBE    47.724978  -5.527465  -0.838850  -1.635377   0.825800
# NASDAQ.ADI    -28.216508   0.780005   0.539506  -0.700618  -0.140310
# ...                  ...        ...        ...        ...        ...
# NYSE.XRX     -102.418620 -13.374199  -2.456842   1.278106  -2.631316
# NYSE.XYL      -58.909653  -3.515838  -1.229148  -0.482998   0.715759
# NYSE.YUM      -37.768773  -3.790280   0.917634  -0.762794   0.469153
# NYSE.ZBH       23.384796   2.245973   2.415229   2.869741  -4.072576
# NYSE.ZTS      -51.988519  -2.615004   2.338161  -0.178834   0.327281
#
#                     5         6         7         8         9  cluster number
# SP500        2.129223  0.276727 -1.433898 -3.521363 -1.072026               1
# NASDAQ.AAL   0.032811 -0.923771 -0.043703 -0.288694 -0.157667               0
# NASDAQ.AAPL  1.318930  1.053040 -1.024297 -1.665057  1.150786               3
# NASDAQ.ADBE  0.461141  0.686486 -0.884627  0.455431  0.457816               3
# NASDAQ.ADI   1.323158  0.346915 -0.670450  0.087629  0.482146               0
# ...               ...       ...       ...       ...       ...             ...
# NYSE.XRX    -1.987918  0.424595  2.160934  0.098362 -0.480371               0
# NYSE.XYL    -0.051302  0.076366  0.147101 -0.233860  0.194640               0
# NYSE.YUM     0.166726 -0.035188  0.499362 -0.027870  0.351769               0
# NYSE.ZBH    -0.481108  0.719478 -0.361450  1.353845 -1.019922               3
# NYSE.ZTS    -0.121130 -0.005569  0.257108 -0.169782  0.397829               0
#
# [501 rows x 11 columns]
